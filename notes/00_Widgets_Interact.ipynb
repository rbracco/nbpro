# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display, Audio
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

# %%
def f(x):
    return x

# %% [markdown]
# ## ipywidgets interact

# %%
interact(f, x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…

# %%
def make_tone(freq, clip_length=1, sr=16000):
    t = np.linspace(0, clip_length, int(clip_length*sr), endpoint=False)
    print(np.expand_dims(t, 0).shape)
    sig = 0.1*np.sin(2*np.pi*freq*t)
    display(plt.plot(t[0:1000], sig[0:1000]))
    display(Audio(sig, rate=sr))
    return 0.1*np.sin(2*np.pi*freq*t)

# %%
onesec = partial(make_tone, clip_length=1, sr=16000)

# %%
interact_manual(make_tone, freq=100, continuous_update=False);
# Out:
# interactive(children=(IntSlider(value=100, description='freq', max=300, min=-100), IntSlider(value=1, descript…

# %%
interact(make_tone, freq=100, clip_length=fixed(1), sr=fixed(16000));
# Out:
# interactive(children=(IntSlider(value=100, description='freq', max=300, min=-100), Output()), _dom_classes=('w…

# %%
interact(make_tone, 
         freq=widgets.IntSlider(min=0, max=100, step=10, value=20),
        clip_length=fixed(1), 
         sr=fixed(16000));
# Out:
# interactive(children=(IntSlider(value=20, description='freq', step=10), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# ## Argument types

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
interact(make_tone, 
         freq=widgets.IntSlider(min=0, max=100, step=10, value=20),
        clip_length=fixed(1), 
         sr=fixed(16000));
# Out:
# interactive(children=(IntSlider(value=20, description='freq', step=10), Output()), _dom_classes=('widget-inter…

# %%
interact(make_tone, freq=(0,100,10), clip_length=fixed(1), sr=fixed(16000));
# Out:
# interactive(children=(IntSlider(value=50, description='freq', step=10), Output()), _dom_classes=('widget-inter…

# %%
# note this is interactive, not interact. interactive lets you access the return value
# of the function being hooked into using .result
w = interactive(make_tone, freq=(0,100,10), clip_length=fixed(1), sr=fixed(16000))

# %%
display(w)
# Out:
# interactive(children=(IntSlider(value=50, description='freq', step=10), Output()), _dom_classes=('widget-inter…

# %%
w.result
# Out:
# array([ 0.        ,  0.0003927 ,  0.00078539, ..., -0.00117807,
#        -0.00078539, -0.0003927 ])

# %% [markdown]
# ## Handling Slow Functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Customizing user interface with interactive_output

# %% [markdown]
# ![image.png](attachment:image.png)
